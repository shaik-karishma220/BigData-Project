# %%
spark.sql("CREATE CATALOG IF NOT EXISTS konami_catalog")
# Out:
# DataFrame[]

# %%
spark.sql("CREATE SCHEMA IF NOT EXISTS konami_catalog.retail_schema")
# Out:
# DataFrame[]

# %%
spark.sql("USE CATALOG konami_catalog")
spark.sql("USE SCHEMA retail_schema")
# Out:
# DataFrame[]

# %%
spark.sql("SHOW CATALOGS")
# Out:
# DataFrame[catalog: string]

# %%
spark.sql("SHOW SCHEMAS IN konami_catalog")
# Out:
# DataFrame[databaseName: string]

# %%
from pyspark.sql import Row
from pyspark.sql.functions import *

# %% [markdown]
# Create customer bronze table

# %%
customers_rows = [

    Row(customer_id=1, customer_name="Arafat Mahmood", age=26, gender="Male",
        country="Nigeria", region_id=1, signup_date="2026-01-10", customer_segment="Premium"),

    Row(customer_id=2, customer_name="David Okoro", age=None, gender="male",
        country="South Africa", region_id=1, signup_date="2026/02/15", customer_segment="Standard"),

    Row(customer_id=3, customer_name="Fabian Akaeze", age=35, gender="MALE",
        country="Singapore", region_id=6, signup_date="2026-01-20", customer_segment="premium"),

    Row(customer_id=4, customer_name="Fatima Ali", age=-3, gender="Female",
        country="Kenya", region_id=2, signup_date="2026-03-01", customer_segment="Standard"),

    Row(customer_id=5, customer_name="Samuel Mensah", age=42, gender="Male",
        country="Ghana", region_id=1, signup_date="2026-02-10", customer_segment="Premium"),

    Row(customer_id=6, customer_name="Priya Sharma", age=31, gender="female",
        country="India", region_id=5, signup_date="2026-01-25", customer_segment="standard"),

    Row(customer_id=7, customer_name="Kalik Reece", age=45, gender="Male",
        country="Egypt", region_id=3, signup_date=None, customer_segment="Premium"),

    Row(customer_id=8, customer_name="Karishma Shaik", age=23, gender="Female",
        country="South Africa", region_id=4, signup_date="2026-03-05", customer_segment="Standard"),

    Row(customer_id=9, customer_name="John Smith", age=38, gender="M",
        country="Kenya", region_id=2, signup_date="2026-02-01", customer_segment="Premium"),

    Row(customer_id=10, customer_name="Ravi Patel", age=None, gender="Male",
        country="INDIA", region_id=5, signup_date="2026-01-15", customer_segment="Premium"),

    Row(customer_id=11, customer_name="Grace Wanjiku", age=27, gender="Female",
        country="kenya", region_id=2, signup_date="2026-02-20", customer_segment="Standard"),

    Row(customer_id=12, customer_name="Daniel Kim", age=33, gender="Male",
        country="Singapore", region_id=6, signup_date="2026-02-18", customer_segment="Premium"),

    Row(customer_id=13, customer_name="Orukome Egbuwoku", age=24, gender="Female",
        country="Nigeria", region_id=1, signup_date="2026-03-02", customer_segment="Standard"),

    Row(customer_id=14, customer_name="Michael Lee", age=41, gender="male",
        country="Malaysia", region_id=7, signup_date="2026-01-30", customer_segment="Premium"),

    Row(customer_id=15, customer_name="Sara Ahmed", age=36, gender=None,
        country="Egypt", region_id=3, signup_date="2026-02-25", customer_segment="Standard"),

    Row(customer_id=16, customer_name="Laith Adi", age=30, gender="Male",
        country="Nigeria", region_id=1, signup_date="2026-03-08", customer_segment="Premium"),

    Row(customer_id=17, customer_name="Ananya Rao", age=26, gender="Female",
        country="India", region_id=5, signup_date="2026-02-12", customer_segment="Standard"),

    Row(customer_id=18, customer_name="Peter Mwangi", age=39, gender="Male",
        country="Kenya", region_id=2, signup_date="2026-01-22", customer_segment="Premium"),

    Row(customer_id=19, customer_name="Vasu Vasu", age=34, gender="Female",
        country="Singapore", region_id=6, signup_date="2026/03/11", customer_segment="Premium"),

    Row(customer_id=20, customer_name="Omar Ali", age=50, gender="Male",
        country="Egypt", region_id=3, signup_date=None, customer_segment="standard"),

    Row(customer_id=21, customer_name="Zainab Musa", age=22, gender="Female",
        country="Nigeria", region_id=1, signup_date="2026-03-15", customer_segment="Standard"),

    Row(customer_id=22, customer_name="Thabo Dlamini", age=37, gender="Male",
        country="south africa", region_id=4, signup_date="2026-03-18", customer_segment=None),

    Row(customer_id=23, customer_name="Mei Ling", age=32, gender="Female",
        country="Malaysia", region_id=7, signup_date="bad_date", customer_segment="Standard"),

    Row(customer_id=24, customer_name="Ibrahim Yusuf", age=44, gender="Male",
        country="Ghana", region_id=1, signup_date="2026-03-20", customer_segment=None),

    Row(customer_id=25, customer_name="Rina Kapoor", age=29, gender="Female",
        country="India", region_id=5, signup_date="2026-03-22", customer_segment="Premium")
]


customers_df = spark.createDataFrame(customers_rows)

display(customers_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
customers_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("konami_catalog.retail_schema.bronze_customers")

# %% [markdown]
# Create Product bronze table

# %%
from pyspark.sql import Row

products_rows = [

    Row(product_id=101, product_name="Gaming Mouse", category="Electronics", price=29.99, stock_quantity=100, supplier_country="China"),
    Row(product_id=102, product_name="Wireless Headset", category="electronics", price="49.99", stock_quantity=50, supplier_country="China"), 
    Row(product_id=103, product_name="Smart Watch", category=None, price=89.99, stock_quantity=-5, supplier_country="USA"),
    Row(product_id=104, product_name="Laptop Stand", category="Accessories", price=25.5, stock_quantity=75, supplier_country="India"),
    Row(product_id=105, product_name="Mechanical Keyboard", category="Electronics", price=79.99, stock_quantity=40, supplier_country="china"),
    
    Row(product_id=106, product_name="USB-C Cable", category="accessories", price=9.99, stock_quantity=200, supplier_country="Vietnam"),
    Row(product_id=107, product_name="External Hard Drive", category="Electronics", price=120, stock_quantity=30, supplier_country="Thailand"),
    Row(product_id=108, product_name="Monitor 24 inch", category="Electronics", price="199.99", stock_quantity=20, supplier_country="China"),
    Row(product_id=109, product_name="Office Chair", category="Furniture", price=150.75, stock_quantity=15, supplier_country="Malaysia"),
    Row(product_id=110, product_name="Desk Lamp", category=None, price=18.99, stock_quantity=60, supplier_country="India"),

    Row(product_id=111, product_name="Tablet", category="Electronics", price=250.00, stock_quantity=25, supplier_country="China"),
    Row(product_id=112, product_name="Phone Charger", category="Accessories", price=None, stock_quantity=180, supplier_country="china"),
    Row(product_id=113, product_name="Bluetooth Speaker", category="electronics", price=45.99, stock_quantity=None, supplier_country="USA"),
    Row(product_id=114, product_name="Webcam", category="Electronics", price=70.00, stock_quantity="35", supplier_country="Vietnam"),
    Row(product_id=115, product_name="Gaming Chair", category="Furniture", price="300", stock_quantity=10, supplier_country="Malaysia"),

    Row(product_id=116, product_name="Microphone", category="Electronics", price=110.00, stock_quantity=22, supplier_country="China"),
    Row(product_id=117, product_name="Power Bank", category="Accessories", price=-80, stock_quantity=90, supplier_country="India"),
    Row(product_id=118, product_name="Smartphone", category="Electronics", price=699.99, stock_quantity=12, supplier_country="China"),
    Row(product_id=119, product_name="Router", category="electronics", price=85.00, stock_quantity=45, supplier_country="Vietnam"),
    Row(product_id=120, product_name="Keyboard Pad", category="Accessories", price=12.50, stock_quantity=150, supplier_country="India"),

    Row(product_id=121, product_name="Projector", category="Electronics", price=500.00, stock_quantity=5, supplier_country="China"),
    Row(product_id=122, product_name="HDMI Cable", category="accessories", price="8.99", stock_quantity=300, supplier_country="China"),
    Row(product_id=123, product_name="Printer", category="Electronics", price=200.00, stock_quantity=18, supplier_country=None),
    Row(product_id=124, product_name="Scanner", category="Electronics", price=180.00, stock_quantity=-2, supplier_country="Thailand"),
    Row(product_id=125, product_name="Desk Organizer", category=None, price=22.00, stock_quantity=80, supplier_country="India")
]

products_df = spark.createDataFrame(products_rows)

display(products_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
products_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("konami_catalog.retail_schema.bronze_products")

# %% [markdown]
# Create Order Bronze table

# %%
orders_rows = [

    Row(order_id=1001, customer_id=1, order_date="2026-02-01", shipping_country="Nigeria", payment_method="Card", order_status="Delivered", shipping_days=5),
    Row(order_id=1002, customer_id=2, order_date="2026/02/15", shipping_country="nigeria", payment_method=None, order_status="Delivered", shipping_days=7),
    Row(order_id=1003, customer_id=3, order_date="2026-02-10", shipping_country="Singapore", payment_method="Paypal", order_status="Pending", shipping_days=3),
    Row(order_id=1004, customer_id=4, order_date="bad_date", shipping_country="Kenya", payment_method="Card", order_status="Cancelled", shipping_days=None),

    Row(order_id=1005, customer_id=5, order_date="2026-02-18", shipping_country="Ghana", payment_method="Card", order_status="Delivered", shipping_days=6),
    Row(order_id=1006, customer_id=6, order_date="2026-02-20", shipping_country="India", payment_method="UPI", order_status="Delivered", shipping_days=4),
    Row(order_id=1007, customer_id=7, order_date="2026-02-22", shipping_country="Egypt", payment_method="Cash", order_status="delivered", shipping_days=8),
    Row(order_id=1008, customer_id=8, order_date="2026-02-25", shipping_country="South Africa", payment_method="Card", order_status="Pending", shipping_days=5),

    Row(order_id=1009, customer_id=9, order_date="2026-02-28", shipping_country="Kenya", payment_method="Card", order_status="Delivered", shipping_days=6),
    Row(order_id=1010, customer_id=10, order_date="2026-03-01", shipping_country="India", payment_method="UPI", order_status="Delivered", shipping_days=3),
    Row(order_id=1011, customer_id=11, order_date=None, shipping_country="Kenya", payment_method="Card", order_status="Delivered", shipping_days=5),
    Row(order_id=1012, customer_id=12, order_date="2026-03-03", shipping_country="Singapore", payment_method="Paypal", order_status="Pending", shipping_days=4),

    Row(order_id=1013, customer_id=13, order_date="2026-03-04", shipping_country="Nigeria", payment_method="Card", order_status="Delivered", shipping_days=7),
    Row(order_id=1014, customer_id=14, order_date="2026-03-05", shipping_country="Malaysia", payment_method="Card", order_status="Cancelled", shipping_days=2),
    Row(order_id=1015, customer_id=15, order_date="2026-03-06", shipping_country="Egypt", payment_method=None, order_status="Delivered", shipping_days=6),
    Row(order_id=1016, customer_id=16, order_date=None, shipping_country="Nigeria", payment_method="Card", order_status="Delivered", shipping_days=5),

    Row(order_id=1017, customer_id=17, order_date="2026-03-08", shipping_country="India", payment_method=None, order_status="Pending", shipping_days=3),
    Row(order_id=1018, customer_id=18, order_date="2026-03-09", shipping_country="Kenya", payment_method="Card", order_status="Delivered", shipping_days=4),
    Row(order_id=1019, customer_id=19, order_date="2026-03-10", shipping_country="Singapore", payment_method="Paypal", order_status="Delivered", shipping_days=6),
    Row(order_id=1020, customer_id=20, order_date="2026-03-11", shipping_country="Egypt", payment_method="Cash", order_status="Delivered", shipping_days=7),

    Row(order_id=1021, customer_id=21, order_date="2026-03-12", shipping_country="Nigeria", payment_method="Card", order_status="Pending", shipping_days=5),
    Row(order_id=1022, customer_id=22, order_date="2026-03-13", shipping_country="South Africa", payment_method="Card", order_status="Delivered", shipping_days=6),
    Row(order_id=1023, customer_id=23, order_date="2026-03-14", shipping_country="Malaysia", payment_method="Card", order_status="Delivered", shipping_days=4),
    Row(order_id=1024, customer_id=24, order_date="2026-03-15", shipping_country="Ghana", payment_method="Card", order_status="Cancelled", shipping_days=2),

    Row(order_id=1025, customer_id=25, order_date="2026-03-16", shipping_country=None, payment_method="UPI", order_status="Delivered", shipping_days=3),
    Row(order_id=1026, customer_id=99, order_date="2026-03-17", shipping_country="Unknown", payment_method="Card", order_status="Pending", shipping_days=5),  # invalid FK
    Row(order_id=1027, customer_id=5, order_date="2026-03-18", shipping_country="Ghana", payment_method="Card", order_status="Delivered", shipping_days="6"),
    Row(order_id=1028, customer_id=2, order_date="2026-03-19", shipping_country="Nigeria", payment_method="Card", order_status="Delivered", shipping_days=7),
    Row(order_id=1029, customer_id=8, order_date="2026-03-20", shipping_country="South Africa", payment_method=None, order_status="Pending", shipping_days=4),
    Row(order_id=1030, customer_id=1, order_date="2026-03-21", shipping_country="Nigeria", payment_method="Card", order_status="Delivered", shipping_days=None)

]

orders_df = spark.createDataFrame(orders_rows)

display(orders_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
orders_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("konami_catalog.retail_schema.bronze_orders")

# %% [markdown]
# Create Order Item Bronze table

# %%
from pyspark.sql import Row

order_items_rows = [

    Row(order_id=1001, product_id=101, quantity=2, unit_price=29.99, discount=0.0),
    Row(order_id=1001, product_id=105, quantity=1, unit_price="79.99", discount=5.0), 
    Row(order_id=1002, product_id=102, quantity=3, unit_price=49.99, discount=0.0),
    Row(order_id=1002, product_id=None, quantity=1, unit_price=15.00, discount=0.0), 

    Row(order_id=1003, product_id=103, quantity=-2, unit_price=89.99, discount=10.0), 
    Row(order_id=1003, product_id=108, quantity=1, unit_price=199.99, discount=0.0),
    Row(order_id=1004, product_id=110, quantity=2, unit_price=18.99, discount=None), 
    Row(order_id=1005, product_id=111, quantity=1, unit_price=250.00, discount=0.0),

    Row(order_id=1006, product_id=112, quantity=5, unit_price=15.00, discount=0.0),
    Row(order_id=1006, product_id=117, quantity=2, unit_price=25.99, discount=5.0),
    Row(order_id=1007, product_id=118, quantity=1, unit_price=699.99, discount=20.0),
    Row(order_id=1007, product_id=119, quantity=2, unit_price=85.00, discount=0.0),

    Row(order_id=1008, product_id=120, quantity=3, unit_price=12.50, discount=0.0),
    Row(order_id=1009, product_id=121, quantity=1, unit_price=500.00, discount=0.0),
    Row(order_id=1010, product_id=122, quantity=4, unit_price="8.99", discount=0.0), 
    Row(order_id=1011, product_id=123, quantity=1, unit_price=200.00, discount=0.0),

    Row(order_id=1012, product_id=124, quantity=2, unit_price=180.00, discount=10.0),
    Row(order_id=1013, product_id=125, quantity=1, unit_price=22.00, discount=0.0),
    Row(order_id=1014, product_id=101, quantity=2, unit_price=29.99, discount=0.0),
    Row(order_id=1015, product_id=102, quantity=1, unit_price=49.99, discount=None),

    Row(order_id=1016, product_id=103, quantity=3, unit_price=89.99, discount=5.0),
    Row(order_id=1017, product_id=104, quantity=2, unit_price=25.50, discount=0.0),
    Row(order_id=1018, product_id=105, quantity=1, unit_price=79.99, discount=0.0),
    Row(order_id=1019, product_id=106, quantity=4, unit_price=9.99, discount=0.0),

    Row(order_id=1020, product_id=107, quantity=1, unit_price=120.00, discount=0.0),
    Row(order_id=1021, product_id=108, quantity=2, unit_price=199.99, discount=15.0),
    Row(order_id=1022, product_id=109, quantity=1, unit_price=150.75, discount=0.0),
    Row(order_id=1023, product_id=110, quantity=3, unit_price=18.99, discount=0.0),

    Row(order_id=1024, product_id=111, quantity=1, unit_price=250.00, discount=0.0),
    Row(order_id=1025, product_id=112, quantity=2, unit_price=15.00, discount=0.0),
    Row(order_id=1026, product_id=113, quantity=1, unit_price=None, discount=0.0),
    Row(order_id=1027, product_id=114, quantity=2, unit_price=70.00, discount=5.0),

    Row(order_id=1028, product_id=115, quantity=1, unit_price="300", discount=0.0),
    Row(order_id=1029, product_id=116, quantity=2, unit_price=110.00, discount=0.0),
    Row(order_id=1030, product_id=117, quantity=3, unit_price=25.99, discount=0.0),

    # extra rows to reach ~50
    Row(order_id=1001, product_id=118, quantity=1, unit_price=None, discount=0.0),
    Row(order_id=1002, product_id=119, quantity=2, unit_price=85.00, discount=0.0),
    Row(order_id=1003, product_id=120, quantity=3, unit_price=12.50, discount=0.0),
    Row(order_id=1004, product_id=121, quantity=1, unit_price=500.00, discount=0.0),

    Row(order_id=1005, product_id=122, quantity=5, unit_price=8.99, discount=0.0),
    Row(order_id=1006, product_id=123, quantity=2, unit_price=200.00, discount=0.0),
    Row(order_id=1007, product_id=124, quantity=1, unit_price=180.00, discount=0.0),
    Row(order_id=1008, product_id=125, quantity=2, unit_price=22.00, discount=0.0),

    Row(order_id=9999, product_id=101, quantity=1, unit_price=29.99, discount=0.0), 
    Row(order_id=1010, product_id=None, quantity=1, unit_price=15.00, discount=0.0), 
    Row(order_id=1011, product_id=105, quantity=-1, unit_price=79.99, discount=0.0) 
]

order_items_df = spark.createDataFrame(order_items_rows)

display(order_items_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
order_items_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("konami_catalog.retail_schema.bronze_order_items")

# %% [markdown]
# Create Regional Market Targets Bronze table

# %%
regional_rows = [

    Row(region_id=1, region_name="West Africa", country_group="Africa", target_customers=50000, target_revenue=500000),
    Row(region_id=2, region_name="east africa", country_group="Africa", target_customers=40000, target_revenue=400000),
    Row(region_id=3, region_name="North Africa", country_group="Africa", target_customers=None, target_revenue=300000),
    Row(region_id=4, region_name="Southern Africa", country_group="Africa", target_customers=35000, target_revenue=350000),

    Row(region_id=5, region_name="INDIA", country_group="South Asia", target_customers=90000, target_revenue=900000),
    Row(region_id=6, region_name="Singapore", country_group="Southeast Asia", target_customers=60000, target_revenue=700000),
    Row(region_id=7, region_name="Malaysia", country_group="south east asia", target_customers=55000, target_revenue=None)
]

regional_df = spark.createDataFrame(regional_rows)

display(regional_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
regional_df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("konami_catalog.retail_schema.bronze_regional_market_targets")
